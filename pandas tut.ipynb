# %%
import pandas as pd
df= pd.read_csv('Pokemon_Data.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df1=df.head()

# %%
df1['Attack'].agg("mean")
# Out:
# 69.0

# %%
df.groupby("Type 1")["HP"].mean()
# Out:
# Type 1
# Bug         56.884058
# Dark        66.806452
# Dragon      83.312500
# Electric    59.795455
# Fairy       74.117647
# Fighting    69.851852
# Fire        69.903846
# Flying      70.750000
# Ghost       64.437500
# Grass       67.271429
# Ground      73.781250
# Ice         72.000000
# Normal      77.275510
# Poison      67.250000
# Psychic     70.631579
# Rock        65.363636
# Steel       65.222222
# Water       72.062500
# Name: HP, dtype: float64

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.groupby("Type 2")["Defense"].mean()
# Out:
# Type 2
# Bug          80.000000
# Dark         72.050000
# Dragon       87.055556
# Electric     68.333333
# Fairy        73.869565
# Fighting     82.500000
# Fire         80.166667
# Flying       68.309278
# Ghost        82.285714
# Grass        80.120000
# Ground       90.314286
# Ice          85.642857
# Normal       53.750000
# Poison       59.558824
# Psychic      87.030303
# Rock        126.857143
# Steel       104.636364
# Water        85.071429
# Name: Defense, dtype: float64

# %%
df1=df.loc[df["Type 2"]=="Ice"]
df1
# Out:
#        #                     Name    Type 1 Type 2   HP  Attack  Defense  \
# 94    87                  Dewgong     Water    Ice   90      70       80
# 98    91                 Cloyster     Water    Ice   50      95      180
# 142  131                   Lapras     Water    Ice  130      85       80
# 233  215                  Sneasel      Dark    Ice   55      95       55
# 509  459                   Snover     Grass    Ice   60      62       50
# 510  460                Abomasnow     Grass    Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow     Grass    Ice   90     132      105
# 512  461                  Weavile      Dark    Ice   70     120       65
# 534  479         RotomFrost Rotom  Electric    Ice   50      65      107
# 710  646                   Kyurem    Dragon    Ice  125     130       90
# 711  646       KyuremBlack Kyurem    Dragon    Ice  125     170      100
# 712  646       KyuremWhite Kyurem    Dragon    Ice  125     120       90
# ...

# %%
df1.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count   14.000000   14.000000   14.000000   14.000000   14.000000   14.000000
# mean   441.285714   90.000000   98.000000   85.642857   92.642857   84.785714
# std    224.733835   30.707053   32.446406   33.104978   36.887786   18.009308
# min     87.000000   50.000000   59.000000   50.000000   35.000000   45.000000
# 25%    276.000000   62.500000   71.750000   66.750000   67.750000   77.500000
# 50%    460.500000   90.000000   93.500000   80.000000   88.500000   90.000000
# 75%    646.000000  124.500000  120.000000   97.500000  116.250000   95.000000
# max    699.000000  130.000000  170.000000  180.000000  170.000000  107.000000
#
#             Speed  Generation
# count   14.000000   14.000000
# mean    74.642857    3.714286
# std     28.146887    1.772811
# min     30.000000    1.000000
# 25%     58.500000    2.500000
# 50%     70.000000    4.000000
# 75%     95.000000    5.000000
# ...

# %%
df.head(n=5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df1= pd.read_excel("pokemon_data.xlsx")

# %%
df1
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df[['Name','Type 1', 'HP']]
# Out:
#                       Name   Type 1  HP
# 0                Bulbasaur    Grass  45
# 1                  Ivysaur    Grass  60
# 2                 Venusaur    Grass  80
# 3    VenusaurMega Venusaur    Grass  80
# 4               Charmander     Fire  39
# ..                     ...      ...  ..
# 795                Diancie     Rock  50
# 796    DiancieMega Diancie     Rock  50
# 797    HoopaHoopa Confined  Psychic  80
# 798     HoopaHoopa Unbound  Psychic  80
# 799              Volcanion     Fire  80
#
# [800 rows x 3 columns]

# %%
df.iloc[6:13]
df.iloc[7,3]
# Out:
# 'Dragon'

# %%
df.loc[df["Defense"]== 63]
# Out:
#        #       Name    Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 1      2    Ivysaur     Grass  Poison   60      62       63       80       80
# 319  295    Exploud    Normal     NaN  104      91       63       91       73
# 571  512   Simisage     Grass     NaN   75      98       63       98       63
# 573  514   Simisear      Fire     NaN   75      98       63       98       63
# 575  516   Simipour     Water     NaN   75      98       63       98       63
# 582  523  Zebstrika  Electric     NaN   75     100       63       80       63
# 642  581     Swanna     Water  Flying   75      87       63       87       63
#
#      Speed  Generation  Legendary
# 1       60           1      False
# 319     68           3      False
# 571    101           5      False
# 573    101           5      False
# 575    101           5      False
# 582    116           5      False
# 642     98           5      False

# %%
df.loc[(df["Defense"]== 63) &(df["HP"]>45)]
# Out:
#        #       Name    Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 1      2    Ivysaur     Grass  Poison   60      62       63       80       80
# 319  295    Exploud    Normal     NaN  104      91       63       91       73
# 571  512   Simisage     Grass     NaN   75      98       63       98       63
# 573  514   Simisear      Fire     NaN   75      98       63       98       63
# 575  516   Simipour     Water     NaN   75      98       63       98       63
# 582  523  Zebstrika  Electric     NaN   75     100       63       80       63
# 642  581     Swanna     Water  Flying   75      87       63       87       63
#
#      Speed  Generation  Legendary
# 1       60           1      False
# 319     68           3      False
# 571    101           5      False
# 573    101           5      False
# 575    101           5      False
# 582    116           5      False
# 642     98           5      False

# %%
df.sort_values("Type 2", ascending= False)
# Out:
#        #       Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 799  721  Volcanion    Fire  Water   80     110      120      130       90
# 152  141   Kabutops    Rock  Water   60     115      105       65       70
# 151  140     Kabuto    Rock  Water   30      80       90       55       45
# 150  139    Omastar    Rock  Water   70      60      125      115       70
# 149  138    Omanyte    Rock  Water   35      40      100       90       55
# ..   ...        ...     ...    ...  ...     ...      ...      ...      ...
# 775  705    Sliggoo  Dragon    NaN   68      75       53       83      113
# 776  706     Goodra  Dragon    NaN   90     100       70      110      150
# 788  712   Bergmite     Ice    NaN   55      69       85       32       35
# 789  713    Avalugg     Ice    NaN   95     117      184       44       46
# 792  716    Xerneas   Fairy    NaN  126     131       95      131       98
#
#      Speed  Generation  Legendary
# ...

# %%
import pandas as pd
df1= pd.read_csv("pokemon_data.csv")
df1
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df1.head(n=10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
df1.iloc[3:6]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
# 5  5             Charmeleon   Fire     NaN  58      64       58       80
#
#    Sp. Def  Speed  Generation  Legendary
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False

# %%
df2=df1.iloc[50:55]

# %%
#df2.loc[df2['Type 1']=='Bug']
df2=df2.loc[(df2['Type 1']=="Grass") & (df2["Defense"]>55)]
df2
# Out:
#      #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 50  45  Vileplume  Grass  Poison  75      80       85      110       90
#
#     Speed  Generation  Totla
# 50     50           1    490

# %%
df1
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Totla
# 0         65       65     45           1    318
# ...

# %%
df1["Total"]= df1["HP"]+ df1["Defense"]+ df1["Sp. Atk"]+ df1["Sp. Def"] + df1["Speed"]
df1
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    269
# ...

# %%
df1.head(10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    269
# ...

# %%
45+49+65+65+45
# Out:
# 269

# %%
df1= df1.drop(columns=["Total"])

# %%
df1
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df1= df1.drop(columns= ["Legendary"])
df1
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation
# 0         65       65     45           1
# 1         80       80     60           1
# ...

# %%
df1["Totla"]= df1.iloc[:, 4:10].sum(axis=1)
df1
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Totla
# 0         65       65     45           1    318
# ...

# %%
df1
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Totla
# 0         65       65     45           1    318
# ...

# %%
df1=df1.loc[df1["Totla"]>600]
df1
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100      123
# 7      6  CharizardMega Charizard X      Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire    Flying   78     104       78
# 12     9    BlastoiseMega Blastoise     Water       NaN   79     103      120
# 141  130      GyaradosMega Gyarados     Water      Dark   95     155      109
# 154  142  AerodactylMega Aerodactyl      Rock    Flying   80     135       85
# 162  150                     Mewtwo   Psychic       NaN  106     110       90
# 163  150        MewtwoMega Mewtwo X   Psychic  Fighting  106     190      100
# 164  150        MewtwoMega Mewtwo Y   Psychic       NaN  106     150       70
# 196  181      AmpharosMega Ampharos  Electric    Dragon   90      95      105
# 224  208        SteelixMega Steelix     Steel    Ground   75     125      230
# ...

# %%
#df1.reset_index(drop= True, inplace= True)
df1

# %%
df1.reset_index(drop= True, inplace= True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-da040cd33fbc> in <module>
# ----> 1 df1.reset_index(drop= True, inplace= True)
#
# AttributeError: 'NoneType' object has no attribute 'reset_index'

# %%
import pandas as pd
d1= pd.read_csv("pokemon_data.csv")
d1
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
d1= d1.loc[(d1['Type 2']== 'Poison') & (d1["Defense"]>55)]
d1
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 54    49               Venomoth    Bug  Poison   70      65       60       90
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 79    73             Tentacruel  Water  Poison   80      70       65       80
# 101   94                 Gengar  Ghost  Poison   60      65       60      130
# 102   94      GengarMega Gengar  Ghost  Poison   60      65       80      170
# 182  168                Ariados    Bug  Poison   70      90       70       60
# ...

# %%
d1.reset_index(drop= True, inplace= True)

# %%
d1
# Out:
#       #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0     2                Ivysaur  Grass  Poison   60      62       63       80
# 1     3               Venusaur  Grass  Poison   80      82       83      100
# 2     3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 3    44                  Gloom  Grass  Poison   60      65       70       85
# 4    45              Vileplume  Grass  Poison   75      80       85      110
# 5    49               Venomoth    Bug  Poison   70      65       60       90
# 6    71             Victreebel  Grass  Poison   80     105       65      100
# 7    73             Tentacruel  Water  Poison   80      70       65       80
# 8    94                 Gengar  Ghost  Poison   60      65       60      130
# 9    94      GengarMega Gengar  Ghost  Poison   60      65       80      170
# 10  168                Ariados    Bug  Poison   70      90       70       60
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
df1= pd.read_csv("Uber Request Data.csv")
df1.head()
# Out:
#    Request id Pickup point  Driver id          Status    Request timestamp  \
# 0         619      Airport        1.0  Trip Completed      11/7/2016 11:51
# 1         867      Airport        1.0  Trip Completed      11/7/2016 17:57
# 2        1807         City        1.0  Trip Completed       12/7/2016 9:17
# 3        2532      Airport        1.0  Trip Completed      12/7/2016 21:08
# 4        3112         City        1.0  Trip Completed  13-07-2016 08:33:16
#
#         Drop timestamp
# 0      11/7/2016 13:00
# 1      11/7/2016 18:47
# 2       12/7/2016 9:58
# 3      12/7/2016 22:03
# 4  13-07-2016 09:25:47

# %%
df1.dtypes
# Out:
# Request id             int64
# Pickup point          object
# Driver id            float64
# Status                object
# Request timestamp     object
# Drop timestamp        object
# dtype: object

# %%
df1.head()
# Out:
#    Request id Pickup point  Driver id          Status    Request timestamp  \
# 0         619      Airport        1.0  Trip Completed      11/7/2016 11:51
# 1         867      Airport        1.0  Trip Completed      11/7/2016 17:57
# 2        1807         City        1.0  Trip Completed       12/7/2016 9:17
# 3        2532      Airport        1.0  Trip Completed      12/7/2016 21:08
# 4        3112         City        1.0  Trip Completed  13-07-2016 08:33:16
#
#         Drop timestamp
# 0      11/7/2016 13:00
# 1      11/7/2016 18:47
# 2       12/7/2016 9:58
# 3      12/7/2016 22:03
# 4  13-07-2016 09:25:47

# %%
df2= pd.read_csv("america.csv")
df2
# Out:
#             DATE         TIME                       PICK UP ADDRESS  \
# 0       7/1/2014  12:00:00 AM         874 E 139th St Mott Haven, BX
# 1       7/1/2014  12:01:00 AM         628 E 141st St Mott Haven, BX
# 2       7/1/2014  12:01:00 AM        601 E 156th St South Bronx, BX
# 3       7/1/2014  12:01:00 AM         708 E 138th St Mott Haven, BX
# 4       7/1/2014  12:02:00 AM         700 E 140th St Mott Haven, BX
# ...          ...          ...                                   ...
# 91707  9/30/2014  11:47:00 PM            593 Oak Ter Mott Haven, BX
# 91708  9/30/2014  11:48:00 PM   645 Westchester Ave South Bronx, BX
# 91709  9/30/2014  11:51:00 PM        625 Tinton Ave South Bronx, BX
# 91710  9/30/2014  11:54:00 PM     350 Saint Anns Ave Mott Haven, BX
# 91711  9/30/2014  11:58:00 PM         846 Tinton Ave Morrisania, BX
#
#        Unnamed: 3  Unnamed: 4  Unnamed: 5
# 0             NaN         NaN         NaN
# 1             NaN         NaN         NaN
# ...

# %%
df2.dtypes
# Out:
# DATE                object
# TIME                object
# PICK UP ADDRESS     object
# Unnamed: 3         float64
# Unnamed: 4         float64
# Unnamed: 5         float64
# dtype: object

# %%
df2["DATE"]= pd.to_datetime(df2["DATE"])
df2.dtypes
# Out:
# DATE               datetime64[ns]
# TIME                       object
# PICK UP ADDRESS            object
# Unnamed: 3                float64
# Unnamed: 4                float64
# Unnamed: 5                float64
# dtype: object

# %%
df2.head()
# Out:
#         DATE         TIME                  PICK UP ADDRESS  Unnamed: 3  \
# 0 2014-07-01  12:00:00 AM    874 E 139th St Mott Haven, BX         NaN
# 1 2014-07-01  12:01:00 AM    628 E 141st St Mott Haven, BX         NaN
# 2 2014-07-01  12:01:00 AM   601 E 156th St South Bronx, BX         NaN
# 3 2014-07-01  12:01:00 AM    708 E 138th St Mott Haven, BX         NaN
# 4 2014-07-01  12:02:00 AM    700 E 140th St Mott Haven, BX         NaN
#
#    Unnamed: 4  Unnamed: 5
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %%
df2.tail()
# Out:
#             DATE         TIME                       PICK UP ADDRESS  \
# 91707 2014-09-30  11:47:00 PM            593 Oak Ter Mott Haven, BX
# 91708 2014-09-30  11:48:00 PM   645 Westchester Ave South Bronx, BX
# 91709 2014-09-30  11:51:00 PM        625 Tinton Ave South Bronx, BX
# 91710 2014-09-30  11:54:00 PM     350 Saint Anns Ave Mott Haven, BX
# 91711 2014-09-30  11:58:00 PM         846 Tinton Ave Morrisania, BX
#
#        Unnamed: 3  Unnamed: 4  Unnamed: 5
# 91707         NaN         NaN         NaN
# 91708         NaN         NaN         NaN
# 91709         NaN         NaN         NaN
# 91710         NaN         NaN         NaN
# 91711         NaN         NaN         NaN

# %%
for x in range (91711):
    df2["miles"]= x+5

# %%
df2.head()
# Out:
#         DATE         TIME                  PICK UP ADDRESS  Unnamed: 3  \
# 0 2014-07-01  12:00:00 AM    874 E 139th St Mott Haven, BX         NaN
# 1 2014-07-01  12:01:00 AM    628 E 141st St Mott Haven, BX         NaN
# 2 2014-07-01  12:01:00 AM   601 E 156th St South Bronx, BX         NaN
# 3 2014-07-01  12:01:00 AM    708 E 138th St Mott Haven, BX         NaN
# 4 2014-07-01  12:02:00 AM    700 E 140th St Mott Haven, BX         NaN
#
#    Unnamed: 4  Unnamed: 5  miles
# 0         NaN         NaN  91715
# 1         NaN         NaN  91715
# 2         NaN         NaN  91715
# 3         NaN         NaN  91715
# 4         NaN         NaN  91715

# %%
df2.groupby("PICK UP ADDRESS")["miles"].mean()
df2
# Out:
#             DATE         TIME                       PICK UP ADDRESS  \
# 0     2014-07-01  12:00:00 AM         874 E 139th St Mott Haven, BX
# 1     2014-07-01  12:01:00 AM         628 E 141st St Mott Haven, BX
# 2     2014-07-01  12:01:00 AM        601 E 156th St South Bronx, BX
# 3     2014-07-01  12:01:00 AM         708 E 138th St Mott Haven, BX
# 4     2014-07-01  12:02:00 AM         700 E 140th St Mott Haven, BX
# ...          ...          ...                                   ...
# 91707 2014-09-30  11:47:00 PM            593 Oak Ter Mott Haven, BX
# 91708 2014-09-30  11:48:00 PM   645 Westchester Ave South Bronx, BX
# 91709 2014-09-30  11:51:00 PM        625 Tinton Ave South Bronx, BX
# 91710 2014-09-30  11:54:00 PM     350 Saint Anns Ave Mott Haven, BX
# 91711 2014-09-30  11:58:00 PM         846 Tinton Ave Morrisania, BX
#
#        Unnamed: 3  Unnamed: 4  Unnamed: 5  miles
# 0             NaN         NaN         NaN  91715
# 1             NaN         NaN         NaN  91715
# ...

# %%
tep=[]
my=[1, 2,3,4]
for i in my:
    tep.append(i+3)
tep
# Out:
# [4, 5, 6, 7]

# %%
df3= pd.read_csv("test.csv")
df3
# Out:
#           Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  \
# 0          1      1          4  2015-09-17   1.0      1            0
# 1          2      3          4  2015-09-17   1.0      1            0
# 2          3      7          4  2015-09-17   1.0      1            0
# 3          4      8          4  2015-09-17   1.0      1            0
# 4          5      9          4  2015-09-17   1.0      1            0
# ...      ...    ...        ...         ...   ...    ...          ...
# 41083  41084   1111          6  2015-08-01   1.0      0            0
# 41084  41085   1112          6  2015-08-01   1.0      0            0
# 41085  41086   1113          6  2015-08-01   1.0      0            0
# 41086  41087   1114          6  2015-08-01   1.0      0            0
# 41087  41088   1115          6  2015-08-01   1.0      0            0
#
#        SchoolHoliday
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...

# %%
df3.tail()
